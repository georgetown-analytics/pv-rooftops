# %%
# %matplotlib inline

import os
import json
import time
import pickle
import requests
import csv


import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
# Read the data into a DataFrame
FEATURES  = ["county",
             "state",
             "quarter",
             "year",
             "count",
            ]

df = pd.read_csv('Propensity.csv', low_memory=False)
        

print(df)    
print(df.describe())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-28ba3e3110c1> in <module>()
#       7             ]
#       8
# ----> 9 df = pd.read_csv('Propensity.csv', low_memory=False)
#      10
#      11
#
# ...

# %%
# Determine the frequency of each class
print(df.groupby('county')['state'].count())
# Out:
# county
# Adair County            7
# Adams County           24
# Addison County         40
# Aitkin County           1
# Alachua County         37
# Alameda County         38
# Albany County          45
# Allegany County        18
# Allegheny County       17
# Allen County            8
# Amador County          34
# Anderson County         3
# Andrew County          13
# Angelina County         4
# Apache County           9
# Aransas County          4
# Archer County           6
# Armstrong County        4
# Ashland County          8
# Ashtabula County        4
# Atascosa County         7
# Atchison County         2
# Athens County          30
# Atlantic County        49
# Audrain County          1
# Auglaize County         1
# Baker County            8
# Barnstable County      50
# Barron County           2
# Bates County            5
#                        ..
# Waushara County         8
# Wayne County           59
# Webb County            10
# Weber County            6
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, alpha=0.2, figsize=(20, 20), diagonal='kde')
plt.show()

# %%
sns.pairplot(df, hue='year', diag_kind="hist", size=3)

# %%
sns.distplot(df['year'], rug=True)

# %%
plt.figure(figsize=(12, 12)) 
plt.show()

# %%
"""from pandas.plotting import parallel_coordinates
plt.figure(figsize=(12,12))
parallel_coordinates(df, 'count')
plt.show() """
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-adc95f73d21e> in <module>()
#       1 from pandas.plotting import parallel_coordinates
#       2 plt.figure(figsize=(12,12))
# ----> 3 parallel_coordinates(df, 'count')
#       4 plt.show()
#
# /usr/local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# /usr/local/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
# ...

# %%
"""from pandas.plotting import radviz
plt.figure(figsize=(12,12))
radviz(df, 'county')
plt.show()"""

# %%
"""from sklearn.datasets.base import Bunch

DATA_DIR = os.path.abspath(os.path.join(".", "..", "capstone"))

# Show the contents of the data directory
for name in os.listdir(DATA_DIR):
    if name.startswith("."): continue
    print("- {}".format(name))"""
# Out:
# - data
# - load_data.py
# - load_tts.py
# - machine-learning
# - openpv_all.csv
# - pv_ml.ipynb
# - res_pv_instances_filtered.csv
# - sonarServer.pem
# - tiamat
# - tts_header.csv
# - TTS_LBNL_OpenPV_public_file_06-Jan-2017.csv
# - Untitled.ipynb
# - venv
# - venv3
# - XBUS-503-01.Data_Ingestion_and_Wrangling

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-375d30d9eb12> in <module>()
#      23
#      24 # Save the dataset as a variable we can use.
# ---> 25 dataset = load_data()
#      26
#      27 print(dataset.data.shape)
#
# <ipython-input-14-375d30d9eb12> in load_data(root)
#       6
#       7     # Load the dataset from the text file.
# ----> 8     dataset = np.loadtxt(filenames['data'])
#       9
#      10     # Extract the target from the data
#
# /usr/local/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     983
#     984             # Convert each value according to its column and store
# --> 985             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     986             # Then pack it according to the dtype's nesting
# ...
